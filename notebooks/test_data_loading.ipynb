# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from src.preprocessing import load_cuad_qa

entries = load_cuad_qa("/Users/harrisoncohen/legal-lens-AI/cuad/data/train_separate_questions.json")
print("Loaded", len(entries), "clauses")
print("Sample label:", entries[0]['label'])
print("Sample clause:", entries[0]['clause'])
# Out:
# Loaded 11180 clauses
# Sample label: Highlight the parts (if any) of this contract related to "Document Name" that should be reviewed by a lawyer. Details: The name of the contract
# Sample clause: DISTRIBUTOR AGREEMENT

# %%
import pandas as pd
import os
os.makedirs("data", exist_ok=True)


df = pd.DataFrame(entries)
df = df[['contract_id', 'clause', 'label', 'start']]
df = df[df['clause'].str.len() > 10]
df = df.drop_duplicates()

df.to_csv("data/processed_clauses.csv", index=False)

print("Saved processed dataset with", len(df), "rows.")
df.head(3)
# Out:
# Saved processed dataset with 10404 rows.
#                                          contract_id  \
# 0  LIMEENERGYCO_09_09_1999-EX-10-DISTRIBUTOR AGRE...
# 1  LIMEENERGYCO_09_09_1999-EX-10-DISTRIBUTOR AGRE...
# 2  LIMEENERGYCO_09_09_1999-EX-10-DISTRIBUTOR AGRE...
#
#                              clause  \
# 0             DISTRIBUTOR AGREEMENT
# 1                       Distributor
# 2  Electric City of Illinois L.L.C.
#
#                                                label  start
# 0  Highlight the parts (if any) of this contract ...     44
# 1  Highlight the parts (if any) of this contract ...    244
# 2  Highlight the parts (if any) of this contract ...  49574
